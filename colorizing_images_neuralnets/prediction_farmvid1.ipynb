# %%
from keras.layers import Conv2D, UpSampling2D, InputLayer, Conv2DTranspose
from keras.layers import Activation, Dense, Dropout, Flatten
from keras.layers.normalization import BatchNormalization
from keras.models import Sequential, load_model
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from skimage.color import rgb2lab, lab2rgb, rgb2gray, gray2rgb
from skimage.io import imsave
from skimage.transform import resize
import numpy as np
import os
import random
import tensorflow as tf
import matplotlib.pyplot as plt
import pickle
# Out:
# Using TensorFlow backend.

# %%
inception = load_model('inception_resnet_v2_model.h5')
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/keras/engine/saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
inception._make_predict_function()

# %%
def show_gray_image(image):
    plt.imshow(rgb2lab(image)[:,:,0]*255/100, cmap='gray')

# %%
# takes pixels values between [0, 255] and scales values between [-1,1]
def preprocess_input(im):
    return 2*(im/255.0)-1.0

# %%
# takes pixel values between [0, 255] and returns gray image of dim-3 between [0,1]
def turn_gray(im):
    return gray2rgb(rgb2lab(im/255)[:,:,0]/100)

# %%
def embed(images):
    images = preprocess_input(turn_gray(images)*255)
    images = resize(images, (images.shape[0], 299, 299, 3))
    return inception.predict(images)

# %%
model = load_model('farm_final_model.h5')

# %%
path = './video/farm1'
for i in range(1, 361):
    print(path + '/farm1-{:03d}.jpg'.format(i))
# Out:
# ./video/farm1/farm1-001.jpg
# ./video/farm1/farm1-002.jpg
# ./video/farm1/farm1-003.jpg
# ./video/farm1/farm1-004.jpg
# ./video/farm1/farm1-005.jpg
# ./video/farm1/farm1-006.jpg
# ./video/farm1/farm1-007.jpg
# ./video/farm1/farm1-008.jpg
# ./video/farm1/farm1-009.jpg
# ./video/farm1/farm1-010.jpg
# ./video/farm1/farm1-011.jpg
# ./video/farm1/farm1-012.jpg
# ./video/farm1/farm1-013.jpg
# ./video/farm1/farm1-014.jpg
# ./video/farm1/farm1-015.jpg
# ./video/farm1/farm1-016.jpg
# ./video/farm1/farm1-017.jpg
# ./video/farm1/farm1-018.jpg
# ./video/farm1/farm1-019.jpg
# ./video/farm1/farm1-020.jpg
# ./video/farm1/farm1-021.jpg
# ./video/farm1/farm1-022.jpg
# ./video/farm1/farm1-023.jpg
# ./video/farm1/farm1-024.jpg
# ./video/farm1/farm1-025.jpg
# ./video/farm1/farm1-026.jpg
# ./video/farm1/farm1-027.jpg
# ./video/farm1/farm1-028.jpg
# ./video/farm1/farm1-029.jpg
# ./video/farm1/farm1-030.jpg
# ./video/farm1/farm1-031.jpg
# ./video/farm1/farm1-032.jpg
# ./video/farm1/farm1-033.jpg
# ./video/farm1/farm1-034.jpg
# ./video/farm1/farm1-035.jpg
# ./video/farm1/farm1-036.jpg
# ./video/farm1/farm1-037.jpg
# ./video/farm1/farm1-038.jpg
# ./video/farm1/farm1-039.jpg
# ./video/farm1/farm1-040.jpg
# ./video/farm1/farm1-041.jpg
# ./video/farm1/farm1-042.jpg
# ./video/farm1/farm1-043.jpg
# ./video/farm1/farm1-044.jpg
# ./video/farm1/farm1-045.jpg
# ./video/farm1/farm1-046.jpg
# ./video/farm1/farm1-047.jpg
# ./video/farm1/farm1-048.jpg
# ./video/farm1/farm1-049.jpg
# ./video/farm1/farm1-050.jpg
# ./video/farm1/farm1-051.jpg
# ./video/farm1/farm1-052.jpg
# ./video/farm1/farm1-053.jpg
# ./video/farm1/farm1-054.jpg
# ./video/farm1/farm1-055.jpg
# ./video/farm1/farm1-056.jpg
# ./video/farm1/farm1-057.jpg
# ./video/farm1/farm1-058.jpg
# ./video/farm1/farm1-059.jpg
# ./video/farm1/farm1-060.jpg
# ./video/farm1/farm1-061.jpg
# ./video/farm1/farm1-062.jpg
# ./video/farm1/farm1-063.jpg
# ./video/farm1/farm1-064.jpg
# ./video/farm1/farm1-065.jpg
# ./video/farm1/farm1-066.jpg
# ./video/farm1/farm1-067.jpg
# ./video/farm1/farm1-068.jpg
# ./video/farm1/farm1-069.jpg
# ./video/farm1/farm1-070.jpg
# ./video/farm1/farm1-071.jpg
# ./video/farm1/farm1-072.jpg
# ./video/farm1/farm1-073.jpg
# ./video/farm1/farm1-074.jpg
# ./video/farm1/farm1-075.jpg
# ./video/farm1/farm1-076.jpg
# ./video/farm1/farm1-077.jpg
# ./video/farm1/farm1-078.jpg
# ./video/farm1/farm1-079.jpg
# ./video/farm1/farm1-080.jpg
# ./video/farm1/farm1-081.jpg
# ./video/farm1/farm1-082.jpg
# ./video/farm1/farm1-083.jpg
# ./video/farm1/farm1-084.jpg
# ./video/farm1/farm1-085.jpg
# ./video/farm1/farm1-086.jpg
# ./video/farm1/farm1-087.jpg
# ./video/farm1/farm1-088.jpg
# ./video/farm1/farm1-089.jpg
# ./video/farm1/farm1-090.jpg
# ./video/farm1/farm1-091.jpg
# ./video/farm1/farm1-092.jpg
# ./video/farm1/farm1-093.jpg
# ./video/farm1/farm1-094.jpg
# ./video/farm1/farm1-095.jpg
# ./video/farm1/farm1-096.jpg
# ./video/farm1/farm1-097.jpg
# ./video/farm1/farm1-098.jpg
# ./video/farm1/farm1-099.jpg
# ./video/farm1/farm1-100.jpg
# ./video/farm1/farm1-101.jpg
# ./video/farm1/farm1-102.jpg
# ./video/farm1/farm1-103.jpg
# ./video/farm1/farm1-104.jpg
# ./video/farm1/farm1-105.jpg
# ./video/farm1/farm1-106.jpg
# ./video/farm1/farm1-107.jpg
# ./video/farm1/farm1-108.jpg
# ./video/farm1/farm1-109.jpg
# ./video/farm1/farm1-110.jpg
# ./video/farm1/farm1-111.jpg
# ./video/farm1/farm1-112.jpg
# ./video/farm1/farm1-113.jpg
# ./video/farm1/farm1-114.jpg
# ./video/farm1/farm1-115.jpg
# ./video/farm1/farm1-116.jpg
# ./video/farm1/farm1-117.jpg
# ./video/farm1/farm1-118.jpg
# ./video/farm1/farm1-119.jpg
# ./video/farm1/farm1-120.jpg
# ./video/farm1/farm1-121.jpg
# ./video/farm1/farm1-122.jpg
# ./video/farm1/farm1-123.jpg
# ./video/farm1/farm1-124.jpg
# ./video/farm1/farm1-125.jpg
# ./video/farm1/farm1-126.jpg
# ./video/farm1/farm1-127.jpg
# ./video/farm1/farm1-128.jpg
# ./video/farm1/farm1-129.jpg
# ./video/farm1/farm1-130.jpg
# ./video/farm1/farm1-131.jpg
# ./video/farm1/farm1-132.jpg
# ./video/farm1/farm1-133.jpg
# ./video/farm1/farm1-134.jpg
# ./video/farm1/farm1-135.jpg
# ./video/farm1/farm1-136.jpg
# ./video/farm1/farm1-137.jpg
# ./video/farm1/farm1-138.jpg
# ./video/farm1/farm1-139.jpg
# ./video/farm1/farm1-140.jpg
# ./video/farm1/farm1-141.jpg
# ./video/farm1/farm1-142.jpg
# ./video/farm1/farm1-143.jpg
# ./video/farm1/farm1-144.jpg
# ./video/farm1/farm1-145.jpg
# ./video/farm1/farm1-146.jpg
# ./video/farm1/farm1-147.jpg
# ./video/farm1/farm1-148.jpg
# ./video/farm1/farm1-149.jpg
# ./video/farm1/farm1-150.jpg
# ./video/farm1/farm1-151.jpg
# ./video/farm1/farm1-152.jpg
# ./video/farm1/farm1-153.jpg
# ./video/farm1/farm1-154.jpg
# ./video/farm1/farm1-155.jpg
# ./video/farm1/farm1-156.jpg
# ./video/farm1/farm1-157.jpg
# ./video/farm1/farm1-158.jpg
# ./video/farm1/farm1-159.jpg
# ./video/farm1/farm1-160.jpg
# ./video/farm1/farm1-161.jpg
# ./video/farm1/farm1-162.jpg
# ./video/farm1/farm1-163.jpg
# ./video/farm1/farm1-164.jpg
# ./video/farm1/farm1-165.jpg
# ./video/farm1/farm1-166.jpg
# ./video/farm1/farm1-167.jpg
# ./video/farm1/farm1-168.jpg
# ./video/farm1/farm1-169.jpg
# ./video/farm1/farm1-170.jpg
# ./video/farm1/farm1-171.jpg
# ./video/farm1/farm1-172.jpg
# ./video/farm1/farm1-173.jpg
# ./video/farm1/farm1-174.jpg
# ./video/farm1/farm1-175.jpg
# ./video/farm1/farm1-176.jpg
# ./video/farm1/farm1-177.jpg
# ./video/farm1/farm1-178.jpg
# ./video/farm1/farm1-179.jpg
# ./video/farm1/farm1-180.jpg
# ./video/farm1/farm1-181.jpg
# ./video/farm1/farm1-182.jpg
# ./video/farm1/farm1-183.jpg
# ./video/farm1/farm1-184.jpg
# ./video/farm1/farm1-185.jpg
# ./video/farm1/farm1-186.jpg
# ./video/farm1/farm1-187.jpg
# ./video/farm1/farm1-188.jpg
# ./video/farm1/farm1-189.jpg
# ./video/farm1/farm1-190.jpg
# ./video/farm1/farm1-191.jpg
# ./video/farm1/farm1-192.jpg
# ./video/farm1/farm1-193.jpg
# ./video/farm1/farm1-194.jpg
# ./video/farm1/farm1-195.jpg
# ./video/farm1/farm1-196.jpg
# ./video/farm1/farm1-197.jpg
# ./video/farm1/farm1-198.jpg
# ./video/farm1/farm1-199.jpg
# ./video/farm1/farm1-200.jpg
# ./video/farm1/farm1-201.jpg
# ./video/farm1/farm1-202.jpg
# ./video/farm1/farm1-203.jpg
# ./video/farm1/farm1-204.jpg
# ./video/farm1/farm1-205.jpg
# ./video/farm1/farm1-206.jpg
# ./video/farm1/farm1-207.jpg
# ./video/farm1/farm1-208.jpg
# ./video/farm1/farm1-209.jpg
# ./video/farm1/farm1-210.jpg
# ./video/farm1/farm1-211.jpg
# ./video/farm1/farm1-212.jpg
# ./video/farm1/farm1-213.jpg
# ./video/farm1/farm1-214.jpg
# ./video/farm1/farm1-215.jpg
# ./video/farm1/farm1-216.jpg
# ./video/farm1/farm1-217.jpg
# ./video/farm1/farm1-218.jpg
# ./video/farm1/farm1-219.jpg
# ./video/farm1/farm1-220.jpg
# ./video/farm1/farm1-221.jpg
# ./video/farm1/farm1-222.jpg
# ./video/farm1/farm1-223.jpg
# ./video/farm1/farm1-224.jpg
# ./video/farm1/farm1-225.jpg
# ./video/farm1/farm1-226.jpg
# ./video/farm1/farm1-227.jpg
# ./video/farm1/farm1-228.jpg
# ./video/farm1/farm1-229.jpg
# ./video/farm1/farm1-230.jpg
# ./video/farm1/farm1-231.jpg
# ./video/farm1/farm1-232.jpg
# ./video/farm1/farm1-233.jpg
# ./video/farm1/farm1-234.jpg
# ./video/farm1/farm1-235.jpg
# ./video/farm1/farm1-236.jpg
# ./video/farm1/farm1-237.jpg
# ./video/farm1/farm1-238.jpg
# ./video/farm1/farm1-239.jpg
# ./video/farm1/farm1-240.jpg
# ./video/farm1/farm1-241.jpg
# ./video/farm1/farm1-242.jpg
# ./video/farm1/farm1-243.jpg
# ./video/farm1/farm1-244.jpg
# ./video/farm1/farm1-245.jpg
# ./video/farm1/farm1-246.jpg
# ./video/farm1/farm1-247.jpg
# ./video/farm1/farm1-248.jpg
# ./video/farm1/farm1-249.jpg
# ./video/farm1/farm1-250.jpg
# ./video/farm1/farm1-251.jpg
# ./video/farm1/farm1-252.jpg
# ./video/farm1/farm1-253.jpg
# ./video/farm1/farm1-254.jpg
# ./video/farm1/farm1-255.jpg
# ./video/farm1/farm1-256.jpg
# ./video/farm1/farm1-257.jpg
# ./video/farm1/farm1-258.jpg
# ./video/farm1/farm1-259.jpg
# ./video/farm1/farm1-260.jpg
# ./video/farm1/farm1-261.jpg
# ./video/farm1/farm1-262.jpg
# ./video/farm1/farm1-263.jpg
# ./video/farm1/farm1-264.jpg
# ./video/farm1/farm1-265.jpg
# ./video/farm1/farm1-266.jpg
# ./video/farm1/farm1-267.jpg
# ./video/farm1/farm1-268.jpg
# ./video/farm1/farm1-269.jpg
# ./video/farm1/farm1-270.jpg
# ./video/farm1/farm1-271.jpg
# ./video/farm1/farm1-272.jpg
# ./video/farm1/farm1-273.jpg
# ./video/farm1/farm1-274.jpg
# ./video/farm1/farm1-275.jpg
# ./video/farm1/farm1-276.jpg
# ./video/farm1/farm1-277.jpg
# ./video/farm1/farm1-278.jpg
# ./video/farm1/farm1-279.jpg
# ./video/farm1/farm1-280.jpg
# ./video/farm1/farm1-281.jpg
# ./video/farm1/farm1-282.jpg
# ./video/farm1/farm1-283.jpg
# ./video/farm1/farm1-284.jpg
# ./video/farm1/farm1-285.jpg
# ./video/farm1/farm1-286.jpg
# ./video/farm1/farm1-287.jpg
# ./video/farm1/farm1-288.jpg
# ./video/farm1/farm1-289.jpg
# ./video/farm1/farm1-290.jpg
# ./video/farm1/farm1-291.jpg
# ./video/farm1/farm1-292.jpg
# ./video/farm1/farm1-293.jpg
# ./video/farm1/farm1-294.jpg
# ./video/farm1/farm1-295.jpg
# ./video/farm1/farm1-296.jpg
# ./video/farm1/farm1-297.jpg
# ./video/farm1/farm1-298.jpg
# ./video/farm1/farm1-299.jpg
# ./video/farm1/farm1-300.jpg
# ./video/farm1/farm1-301.jpg
# ./video/farm1/farm1-302.jpg
# ./video/farm1/farm1-303.jpg
# ./video/farm1/farm1-304.jpg
# ./video/farm1/farm1-305.jpg
# ./video/farm1/farm1-306.jpg
# ./video/farm1/farm1-307.jpg
# ./video/farm1/farm1-308.jpg
# ./video/farm1/farm1-309.jpg
# ./video/farm1/farm1-310.jpg
# ./video/farm1/farm1-311.jpg
# ./video/farm1/farm1-312.jpg
# ./video/farm1/farm1-313.jpg
# ./video/farm1/farm1-314.jpg
# ./video/farm1/farm1-315.jpg
# ./video/farm1/farm1-316.jpg
# ./video/farm1/farm1-317.jpg
# ./video/farm1/farm1-318.jpg
# ./video/farm1/farm1-319.jpg
# ./video/farm1/farm1-320.jpg
# ./video/farm1/farm1-321.jpg
# ./video/farm1/farm1-322.jpg
# ./video/farm1/farm1-323.jpg
# ./video/farm1/farm1-324.jpg
# ./video/farm1/farm1-325.jpg
# ./video/farm1/farm1-326.jpg
# ./video/farm1/farm1-327.jpg
# ./video/farm1/farm1-328.jpg
# ./video/farm1/farm1-329.jpg
# ./video/farm1/farm1-330.jpg
# ./video/farm1/farm1-331.jpg
# ./video/farm1/farm1-332.jpg
# ./video/farm1/farm1-333.jpg
# ./video/farm1/farm1-334.jpg
# ./video/farm1/farm1-335.jpg
# ./video/farm1/farm1-336.jpg
# ./video/farm1/farm1-337.jpg
# ./video/farm1/farm1-338.jpg
# ./video/farm1/farm1-339.jpg
# ./video/farm1/farm1-340.jpg
# ./video/farm1/farm1-341.jpg
# ./video/farm1/farm1-342.jpg
# ./video/farm1/farm1-343.jpg
# ./video/farm1/farm1-344.jpg
# ./video/farm1/farm1-345.jpg
# ./video/farm1/farm1-346.jpg
# ./video/farm1/farm1-347.jpg
# ./video/farm1/farm1-348.jpg
# ./video/farm1/farm1-349.jpg
# ./video/farm1/farm1-350.jpg
# ./video/farm1/farm1-351.jpg
# ./video/farm1/farm1-352.jpg
# ./video/farm1/farm1-353.jpg
# ./video/farm1/farm1-354.jpg
# ./video/farm1/farm1-355.jpg
# ./video/farm1/farm1-356.jpg
# ./video/farm1/farm1-357.jpg
# ./video/farm1/farm1-358.jpg
# ./video/farm1/farm1-359.jpg
# ./video/farm1/farm1-360.jpg

# %%
try:
    with open('X_farmvid1.pkl', 'rb') as handle:
        X = pickle.load(handle)
except:
    path = './video/farm1/'
    X = []
    for i in range(1, 361):
        X.append(img_to_array(load_img(path + 'farm1-{:03d}.jpg'.format(i)).resize((256, 256)))/255)
    X = np.array(X)
    with open('X_farmvid1.pkl', 'wb') as handle:
        pickle.dump(X, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
X_lab = rgb2lab(X)

# %%
X_L = X_lab[:,:,:,0].reshape(X_lab[:,:,:,0].shape + (1,))
X_ab = X_lab[:,:,:,1:]

# %%
predictions = model.predict([X_L[16:24]/100, embed(X[16:24]*255)], batch_size=8)
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "

# %%
predictions.shape
# Out:
# (8, 256, 256, 2)

# %%
recolored_images = []
for image in np.concatenate([X_L[16:24], predictions*128], axis=-1):
    recolored_images.append(lab2rgb(image))
recolored_images = np.array(recolored_images)

# %%
try:
    with open('recolored_tundra_final.pkl', 'rb') as handle:
        recolored_images = pickle.load(handle)
    
except:
    predictions = model.predict([X_L/100, embed(X*255)], batch_size=8)
    
    recolored_images = []
    for image in np.concatenate([X_L, predictions*128], axis=-1):
        recolored_images.append(lab2rgb(image))
    recolored_images = np.array(recolored_images)
    with open('recolored_tundra_final.pkl', 'wb') as handle:
        pickle.dump(recolored_images, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# /home/goodwin/anaconda3/lib/python3.6/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/goodwin/anaconda3/lib/python3.6/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-74a2f6e132cf> in <module>()
#       1 try:
# ----> 2     with open('recolored_tundra_final.pkl', 'rb') as handle:
#       3         recolored_images = pickle.load(handle)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'recolored_tundra_final.pkl'
#
# During handling of the above exception, another exception occurred:
#
# MemoryError                               Traceback (most recent call last)
# <ipython-input-13-74a2f6e132cf> in <module>()
#       4
#       5 except:
# ----> 6     predictions = model.predict([X_L/100, embed(X*255)], batch_size=8)
#       7
#       8     recolored_images = []
#
# <ipython-input-8-a44e949f1e0c> in embed(images)
#       1 def embed(images):
#       2     images = preprocess_input(turn_gray(images)*255)
# ----> 3     images = resize(images, (images.shape[0], 299, 299, 3))
#       4     return inception.predict(images)
#
# ~/anaconda3/lib/python3.6/site-packages/skimage/transform/_warps.py in resize(image, output_shape, order, mode, cval, clip, preserve_range, anti_aliasing, anti_aliasing_sigma)
#     175         coord_map = np.array(np.meshgrid(*coord_arrays,
#     176                                          sparse=False,
# --> 177                                          indexing='ij'))
#     178
#     179         image = convert_to_float(image, preserve_range)
#
# MemoryError:

# %%
for i in range(8):
    fig = plt.figure(figsize=(10, 30))
    fig.add_subplot(131)
    plt.gca().axis('off')
    show_gray_image(X[i+16])
    fig.add_subplot(132)
    plt.gca().axis('off')
    plt.imshow(recolored_images[i])
    fig.add_subplot(133)
    plt.gca().axis('off')
    plt.imshow(X[i+16])
    plt.show()

# %%
model.evaluate([X_L[:128]/100, embed(X[:128]*255)], X_ab[:128]/128, batch_size=8)
# Out:
# /home/goodwin/anaconda3/lib/python3.6/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/goodwin/anaconda3/lib/python3.6/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# 128/128 [==============================] - 21s 165ms/step
# 0.004743539771880023

# %%
X_ab[:8].shape
# Out:
# (8, 256, 256, 2)
